# %%
# !pip -q install -U "trl[peft]" bitsandbytes datasets transformers accelerate safetensors
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.3/512.3 kB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 45.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.9/518.9 kB 49.5 MB/s eta 0:00:00

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: multi/
#   inflating: multi/0.lastB.messages_response.jsonl
#   inflating: multi/1.lastB.messages_response.jsonl
#   inflating: multi/10.lastB.messages_response.jsonl
#   inflating: multi/100.lastB.messages_response.jsonl
#   inflating: multi/101.lastB.messages_response.jsonl
#   inflating: multi/102.lastB.messages_response.jsonl
#   inflating: multi/103.lastB.messages_response.jsonl
#   inflating: multi/104.lastB.messages_response.jsonl
#   inflating: multi/105.lastB.messages_response.jsonl
#   inflating: multi/106.lastB.messages_response.jsonl
#   inflating: multi/107.lastB.messages_response.jsonl
#   inflating: multi/108.lastB.messages_response.jsonl
#   inflating: multi/109.lastB.messages_response.jsonl
#   inflating: multi/11.lastB.messages_response.jsonl
#   inflating: multi/110.lastB.messages_response.jsonl
#   inflating: multi/111.lastB.messages_response.jsonl
#   inflating: multi/112.lastB.messages_response.jsonl
#   inflating: multi/113.lastB.messages_response.jsonl
#   inflating: multi/114.lastB.messages_response.jsonl
#   inflating: multi/115.lastB.messages_response.jsonl
#   inflating: multi/116.lastB.messages_response.jsonl
#   inflating: multi/117.lastB.messages_response.jsonl
#   inflating: multi/118.lastB.messages_response.jsonl
#   inflating: multi/119.lastB.messages_response.jsonl
#   inflating: multi/12.lastB.messages_response.jsonl
#   inflating: multi/120.lastB.messages_response.jsonl
#   inflating: multi/121.lastB.messages_response.jsonl
#   inflating: multi/122.lastB.messages_response.jsonl
#   inflating: multi/123.lastB.messages_response.jsonl
#   inflating: multi/124.lastB.messages_response.jsonl
#   inflating: multi/125.lastB.messages_response.jsonl
#   inflating: multi/126.lastB.messages_response.jsonl
#   inflating: multi/127.lastB.messages_response.jsonl
#   inflating: multi/128.lastB.messages_response.jsonl
#   inflating: multi/129.lastB.messages_response.jsonl
#   inflating: multi/13.lastB.messages_response.jsonl
#   inflating: multi/130.lastB.messages_response.jsonl
#   inflating: multi/131.lastB.messages_response.jsonl
#   inflating: multi/132.lastB.messages_response.jsonl
#   inflating: multi/133.lastB.messages_response.jsonl
#   inflating: multi/134.lastB.messages_response.jsonl
#   inflating: multi/135.lastB.messages_response.jsonl
#   inflating: multi/136.lastB.messages_response.jsonl
#   inflating: multi/137.lastB.messages_response.jsonl
#   inflating: multi/138.lastB.messages_response.jsonl
#   inflating: multi/139.lastB.messages_response.jsonl
#   inflating: multi/14.lastB.messages_response.jsonl
#   inflating: multi/140.lastB.messages_response.jsonl
#   inflating: multi/141.lastB.messages_response.jsonl
#   inflating: multi/142.lastB.messages_response.jsonl
#   inflating: multi/143.lastB.messages_response.jsonl
#   inflating: multi/144.lastB.messages_response.jsonl
#   inflating: multi/145.lastB.messages_response.jsonl
#   inflating: multi/146.lastB.messages_response.jsonl
#   inflating: multi/147.lastB.messages_response.jsonl
#   inflating: multi/148.lastB.messages_response.jsonl
#   inflating: multi/149.lastB.messages_response.jsonl
#   inflating: multi/Blocked121.lastB.messages_response.jsonl
#   inflating: multi/Blocked122.lastB.messages_response.jsonl
#   inflating: multi/Blocked123.lastB.messages_response.jsonl
#   inflating: multi/Blocked124.lastB.messages_response.jsonl
#   inflating: multi/Blocked125.lastB.messages_response.jsonl
#   inflating: multi/Blocked126.lastB.messages_response.jsonl
#   inflating: multi/Blocked127.lastB.messages_response.jsonl
#   inflating: multi/Blocked128.lastB.messages_response.jsonl
#   inflating: multi/Blocked129.lastB.messages_response.jsonl
#   inflating: multi/Blocked13.lastB.messages_response.jsonl
#   inflating: multi/Blocked14.lastB.messages_response.jsonl
#   inflating: multi/Blocked15.lastB.messages_response.jsonl
#   inflating: multi/Blocked16.lastB.messages_response.jsonl
#   inflating: multi/Blocked17.lastB.messages_response.jsonl
#   inflating: multi/Blocked18.lastB.messages_response.jsonl
#   inflating: multi/Blocked19.lastB.messages_response.jsonl
#   inflating: multi/Blocked2.lastB.messages_response.jsonl
#   inflating: multi/Blocked20.lastB.messages_response.jsonl
#   inflating: multi/Blocked21.lastB.messages_response.jsonl
#   inflating: multi/Blocked22.lastB.messages_response.jsonl
#   inflating: multi/Blocked23.lastB.messages_response.jsonl
#   inflating: multi/Blocked24.lastB.messages_response.jsonl
#   inflating: multi/Blocked25.lastB.messages_response.jsonl
#   inflating: multi/Blocked26.lastB.messages_response.jsonl
#   inflating: multi/Blocked27.lastB.messages_response.jsonl
#   inflating: multi/Blocked28.lastB.messages_response.jsonl
#   inflating: multi/Blocked29.lastB.messages_response.jsonl
#   inflating: multi/Blocked3.lastB.messages_response.jsonl
#   inflating: multi/Blocked30.lastB.messages_response.jsonl
#   inflating: multi/Blocked31.lastB.messages_response.jsonl
#   inflating: multi/Blocked32.lastB.messages_response.jsonl
#   inflating: multi/Blocked33.lastB.messages_response.jsonl
#   inflating: multi/Blocked34.lastB.messages_response.jsonl
#   inflating: multi/Blocked35.lastB.messages_response.jsonl
#   inflating: multi/Blocked36.lastB.messages_response.jsonl
#   inflating: multi/Blocked37.lastB.messages_response.jsonl
#   inflating: multi/Blocked38.lastB.messages_response.jsonl
#   inflating: multi/Blocked39.lastB.messages_response.jsonl
#   inflating: multi/Blocked4.lastB.messages_response.jsonl
#   inflating: multi/Blocked40.lastB.messages_response.jsonl
#   inflating: multi/Blocked41.lastB.messages_response.jsonl
#   inflating: multi/Blocked42.lastB.messages_response.jsonl
#   inflating: multi/Blocked43.lastB.messages_response.jsonl
#   inflating: multi/Blocked44.lastB.messages_response.jsonl
#   inflating: multi/Blocked45.lastB.messages_response.jsonl
#   inflating: multi/Blocked46.lastB.messages_response.jsonl
#   inflating: multi/Blocked47.lastB.messages_response.jsonl
#   inflating: multi/Blocked48.lastB.messages_response.jsonl
#   inflating: multi/Blocked49.lastB.messages_response.jsonl
#   inflating: multi/Blocked5.lastB.messages_response.jsonl
#   inflating: multi/Blocked50.lastB.messages_response.jsonl
#   inflating: multi/Blocked51.lastB.messages_response.jsonl
#   inflating: multi/Blocked52.lastB.messages_response.jsonl
#   inflating: multi/Blocked53.lastB.messages_response.jsonl
#   inflating: multi/Blocked54.lastB.messages_response.jsonl
#   inflating: multi/Blocked55.lastB.messages_response.jsonl
#   inflating: multi/Blocked56.lastB.messages_response.jsonl
#   inflating: multi/Blocked57.lastB.messages_response.jsonl
#   inflating: multi/Blocked58.lastB.messages_response.jsonl
#   inflating: multi/Blocked59.lastB.messages_response.jsonl
#   inflating: multi/Blocked6.lastB.messages_response.jsonl
#   inflating: multi/Blocked60.lastB.messages_response.jsonl
#   inflating: multi/Blocked61.lastB.messages_response.jsonl
#   inflating: multi/Blocked62.lastB.messages_response.jsonl
#   inflating: multi/Blocked63.lastB.messages_response.jsonl
#   inflating: multi/Blocked64.lastB.messages_response.jsonl
#   inflating: multi/Blocked65.lastB.messages_response.jsonl
#   inflating: multi/Blocked66.lastB.messages_response.jsonl
#   inflating: multi/Blocked67.lastB.messages_response.jsonl
#   inflating: multi/Blocked68.lastB.messages_response.jsonl
#   inflating: multi/Blocked69.lastB.messages_response.jsonl
#   inflating: multi/Blocked7.lastB.messages_response.jsonl
#   inflating: multi/Blocked70.lastB.messages_response.jsonl
#   inflating: multi/Blocked71.lastB.messages_response.jsonl
#   inflating: multi/Blocked72.lastB.messages_response.jsonl
#   inflating: multi/Blocked73.lastB.messages_response.jsonl
#   inflating: multi/Blocked74.lastB.messages_response.jsonl
#   inflating: multi/Blocked75.lastB.messages_response.jsonl
#   inflating: multi/Blocked76.lastB.messages_response.jsonl
#   inflating: multi/Blocked77.lastB.messages_response.jsonl
#   inflating: multi/Blocked78.lastB.messages_response.jsonl
#   inflating: multi/Blocked79.lastB.messages_response.jsonl
#   inflating: multi/Blocked8.lastB.messages_response.jsonl
#   inflating: multi/Blocked80.lastB.messages_response.jsonl
#   inflating: multi/Blocked81.lastB.messages_response.jsonl
#   inflating: multi/Blocked82.lastB.messages_response.jsonl
#   inflating: multi/Blocked83.lastB.messages_response.jsonl
#   inflating: multi/Blocked84.lastB.messages_response.jsonl
#   inflating: multi/Blocked85.lastB.messages_response.jsonl
#   inflating: multi/Blocked86.lastB.messages_response.jsonl
#   inflating: multi/Blocked87.lastB.messages_response.jsonl
#   inflating: multi/Blocked88.lastB.messages_response.jsonl
#   inflating: multi/Blocked89.lastB.messages_response.jsonl
#   inflating: multi/Blocked9.lastB.messages_response.jsonl
#   inflating: multi/Blocked90.lastB.messages_response.jsonl
#   inflating: multi/Blocked91.lastB.messages_response.jsonl
#   inflating: multi/Blocked92.lastB.messages_response.jsonl
#   inflating: multi/Blocked93.lastB.messages_response.jsonl
#   inflating: multi/Blocked94.lastB.messages_response.jsonl
#   inflating: multi/Blocked95.lastB.messages_response.jsonl
#   inflating: multi/Blocked96.lastB.messages_response.jsonl
#   inflating: multi/Blocked97.lastB.messages_response.jsonl
#   inflating: multi/Blocked98.lastB.messages_response.jsonl
#   inflating: multi/Blocked99.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card0.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card1.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card10.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card11.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card12.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card13.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card14.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card15.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card16.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card17.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card18.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_Card19.lastB.messages_response.jsonl
#   inflating: multi/Direct_Red_
#   inflating: single/singleton_fromOn_Target92.txt.jsonl
#   inflating: single/singleton_fromOn_Target93.txt.jsonl
#   inflating: single/singleton_fromOn_Target94.txt.jsonl
#   inflating: single/singleton_fromOn_Target95.txt.jsonl
#   inflating: single/singleton_fromOn_Target96.txt.jsonl
#   inflating: single/singleton_fromOn_Target97.txt.jsonl
#   inflating: single/singleton_fromOn_Target98.txt.jsonl
#   inflating: single/singleton_fromOn_Target99.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card0.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card1.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card10.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card2.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card3.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card4.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card5.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card6.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card7.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card8.txt.jsonl
#   inflating: single/singleton_fromSecond_Yellow_Card9.txt.jsonl
#   inflating: single/singleton_fromYellow_Card0.txt.jsonl
#   inflating: single/singleton_fromYellow_Card1.txt.jsonl
#   inflating: single/singleton_fromYellow_Card10.txt.jsonl
#   inflating: single/singleton_fromYellow_Card100.txt.jsonl
#   inflating: single/singleton_fromYellow_Card101.txt.jsonl
#   inflating: single/singleton_fromYellow_Card102.txt.jsonl
#   inflating: single/singleton_fromYellow_Card103.txt.jsonl
#   inflating: single/singleton_fromYellow_Card104.txt.jsonl
#   inflating: single/singleton_fromYellow_Card105.txt.jsonl
#   inflating: single/singleton_fromYellow_Card106.txt.jsonl
#   inflating: single/singleton_fromYellow_Card107.txt.jsonl
#   inflating: single/singleton_fromYellow_Card108.txt.jsonl
#   inflating: single/singleton_fromYellow_Card109.txt.jsonl
#   inflating: single/singleton_fromYellow_Card11.txt.jsonl
#   inflating: single/singleton_fromYellow_Card110.txt.jsonl
#   inflating: single/singleton_fromYellow_Card111.txt.jsonl
#   inflating: single/singleton_fromYellow_Card112.txt.jsonl
#   inflating: single/singleton_fromYellow_Card113.txt.jsonl
#   inflating: single/singleton_fromYellow_Card114.txt.jsonl
#   inflating: single/singleton_fromYellow_Card115.txt.jsonl
#   inflating: single/singleton_fromYellow_Card116.txt.jsonl
#   inflating: single/singleton_fromYellow_Card117.txt.jsonl
#   inflating: single/singleton_fromYellow_Card118.txt.jsonl
#   inflating: single/singleton_fromYellow_Card119.txt.jsonl
#   inflating: single/singleton_fromYellow_Card12.txt.jsonl
#   inflating: single/singleton_fromYellow_Card120.txt.jsonl
#   inflating: single/singleton_fromYellow_Card121.txt.jsonl
#   inflating: single/singleton_fromYellow_Card122.txt.jsonl
#   inflating: single/singleton_fromYellow_Card123.txt.jsonl
#   inflating: single/singleton_fromYellow_Card124.txt.jsonl
#   inflating: single/singleton_fromYellow_Card125.txt.jsonl
#   inflating: single/singleton_fromYellow_Card126.txt.jsonl
#   inflating: single/singleton_fromYellow_Card127.txt.jsonl
#   inflating: single/singleton_fromYellow_Card128.txt.jsonl
#   inflating: single/singleton_fromYellow_Card129.txt.jsonl
#   inflating: single/singleton_fromYellow_Card13.txt.jsonl
#   inflating: single/singleton_fromYellow_Card130.txt.jsonl
#   inflating: single/singleton_fromYellow_Card131.txt.jsonl
#   inflating: single/singleton_fromYellow_Card132.txt.jsonl
#   inflating: single/singleton_fromYellow_Card133.txt.jsonl
#   inflating: single/singleton_fromYellow_Card134.txt.jsonl
#   inflating: single/singleton_fromYellow_Card135.txt.jsonl
#   inflating: single/singleton_fromYellow_Card136.txt.jsonl
#   inflating: single/singleton_fromYellow_Card137.txt.jsonl
#   inflating: single/singleton_fromYellow_Card138.txt.jsonl
#   inflating: single/singleton_fromYellow_Card139.txt.jsonl
#   inflating: single/singleton_fromYellow_Card14.txt.jsonl
#   inflating: single/singleton_fromYellow_Card140.txt.jsonl
#   inflating: single/singleton_fromYellow_Card141.txt.jsonl
#   inflating: single/singleton_fromYellow_Card142.txt.jsonl
#   inflating: single/singleton_fromYellow_Card143.txt.jsonl
#   inflating: single/singleton_fromYellow_Card144.txt.jsonl
#   inflating: single/singleton_fromYellow_Card145.txt.jsonl
#   inflating: single/singleton_fromYellow_Card146.txt.jsonl
#   inflating: single/singleton_fromYellow_Card147.txt.jsonl
#   inflating: single/singleton_fromYellow_Card148.txt.jsonl
#   inflating: single/singleton_fromYellow_Card149.txt.jsonl
#   inflating: single/singleton_fromYellow_Card15.txt.jsonl
#   inflating: single/singleton_fromYellow_Card150.txt.jsonl
#   inflating: single/singleton_fromYellow_Card151.txt.jsonl
#   inflating: single/singleton_fromYellow_Card152.txt.jsonl
#   inflating: single/singleton_fromYellow_Card153.txt.jsonl
#   inflating: single/singleton_fromYellow_Card154.txt.jsonl
#   inflating: single/singleton_fromYellow_Card155.txt.jsonl
#   inflating: single/singleton_fromYellow_Card156.txt.jsonl
#   inflating: single/singleton_fromYellow_Card157.txt.jsonl
#   inflating: single/singleton_fromYellow_Card158.txt.jsonl
#   inflating: single/singleton_fromYellow_Card159.txt.jsonl
#   inflating: single/singleton_fromYellow_Card16.txt.jsonl
#   inflating: single/singleton_fromYellow_Card160.txt.jsonl
#   inflating: single/singleton_fromYellow_Card161.txt.jsonl
#   inflating: single/singleton_fromYellow_Card162.txt.jsonl
#   inflating: single/singleton_fromYellow_Card163.txt.jsonl
#   inflating: single/singleton_fromYellow_Card164.txt.jsonl
#   inflating: single/singleton_fromYellow_Card165.txt.jsonl
#   inflating: single/singleton_fromYellow_Card166.txt.jsonl
#   inflating: single/singleton_fromYellow_Card167.txt.jsonl
#   inflating: single/singleton_fromYellow_Card168.txt.jsonl
#   inflating: single/singleton_fromYellow_Card169.txt.jsonl
#   inflating: single/singleton_fromYellow_Card17.txt.jsonl
#   inflating: single/singleton_fromYellow_Card170.txt.jsonl
#   inflating: single/singleton_fromYellow_Card171.txt.jsonl
#   inflating: single/singleton_fromYellow_Card172.txt.jsonl
#   inflating: single/singleton_fromYellow_Card173.txt.jsonl
#   inflating: single/singleton_fromYellow_Card174.txt.jsonl
#   inflating: single/singleton_fromYellow_Card175.txt.jsonl
#   inflating: single/singleton_fromYellow_Card176.txt.jsonl
#   inflating: single/singleton_fromYellow_Card177.txt.jsonl
#   inflating: single/singleton_fromYellow_Card178.txt.jsonl
#   inflating: single/singleton_fromYellow_Card179.txt.jsonl
#   inflating: single/singleton_fromYellow_Card18.txt.jsonl
#   inflating: single/singleton_fromYellow_Card180.txt.jsonl
#   inflating: single/singleton_fromYellow_Card181.txt.jsonl
#   inflating: single/singleton_fromYellow_Card182.txt.jsonl
#   inflating: single/singleton_fromYellow_Card183.txt.jsonl
#   inflating: single/singleton_fromYellow_Card184.txt.jsonl
#   inflating: single/singleton_fromYellow_Card185.txt.jsonl
#   inflating: single/singleton_fromYellow_Card186.txt.jsonl
#   inflating: single/singleton_fromYellow_Card187.txt.jsonl
#   inflating: single/singleton_fromYellow_Card188.txt.jsonl
#   inflating: single/singleton_fromYellow_Card189.txt.jsonl
#   inflating: single/singleton_fromYellow_Card19.txt.jsonl
#   inflating: single/singleton_fromYellow_Card190.txt.jsonl
#   inflating: single/singleton_fromYellow_Card191.txt.jsonl
#   inflating: single/singleton_fromYellow_Card192.txt.jsonl
#   inflating: single/singleton_fromYellow_Card193.txt.jsonl
#   inflating: single/singleton_fromYellow_Card194.txt.jsonl
#   inflating: single/singleton_fromYellow_Card195.txt.jsonl
#   inflating: single/singleton_fromYellow_Card196.txt.jsonl
#   inflating: single/singleton_fromYellow_Card197.txt.jsonl
#   inflating: single/singleton_fromYellow_Card198.txt.jsonl
#   inflating: single/singleton_fromYellow_Card199.txt.jsonl
#   inflating: single/singleton_fromYellow_Card2.txt.jsonl
#   inflating: single/singleton_fromYellow_Card20.txt.jsonl
#   inflating: single/singleton_fromYellow_Card200.txt.jsonl
#   inflating: single/singleton_fromYellow_Card201.txt.jsonl
#   inflating: single/singleton_fromYellow_Card202.txt.jsonl
#   inflating: single/singleton_fromYellow_Card203.txt.jsonl
#   inflating: single/singleton_fromYellow_Card204.txt.jsonl
#   inflating: single/singleton_fromYellow_Card205.txt.jsonl
#   inflating: single/singleton_fromYellow_Card206.txt.jsonl
#   inflating: single/singleton_fromYellow_Card207.txt.jsonl
#   inflating: single/singleton_fromYellow_Card208.txt.jsonl
#   inflating: single/singleton_fromYellow_Card209.txt.jsonl
#   inflating: single/singleton_fromYellow_Card21.txt.jsonl
#   inflating: single/singleton_fromYellow_Card210.txt.jsonl
#   inflating: single/singleton_fromYellow_Card211.txt.jsonl
#   inflating: single/singleton_fromYellow_Card212.txt.jsonl
#   inflating: single/singleton_fromYellow_Card213.txt.jsonl
#   inflating: single/singleton_fromYellow_Card214.txt.jsonl
#   inflating: single/singleton_fromYellow_Card215.txt.jsonl
#   inflating: single/singleton_fromYellow_Card216.txt.jsonl
#   inflating: single/singleton_fromYellow_Card217.txt.jsonl
#   inflating: single/singleton_fromYellow_Card218.txt.jsonl
#   inflating: single/singleton_fromYellow_Card219.txt.jsonl
#   inflating: single/singleton_fromYellow_Card22.txt.jsonl
#   inflating: single/singleton_fromYellow_Card220.txt.jsonl
#   inflating: single/singleton_fromYellow_Card221.txt.jsonl
#   inflating: single/singleton_fromYellow_Card222.txt.jsonl
#   inflating: single/singleton_fromYellow_Card223.txt.jsonl
#   inflating: single/singleton_fromYellow_Card224.txt.jsonl
#   inflating: single/singleton_fromYellow_Card225.txt.jsonl
#   inflating: single/singleton_fromYellow_Card226.txt.jsonl
#   inflating: single/singleton_fromYellow_Card227.txt.jsonl
#   inflating: single/singleton_fromYellow_Card228.txt.jsonl
#   inflating: single/singleton_fromYellow_Card229.txt.jsonl
#   inflating: single/singleton_fromYellow_Card23.txt.jsonl
#   inflating: single/singleton_fromYellow_Card230.txt.jsonl
#   inflating: single/singleton_fromYellow_Card231.txt.jsonl
#   inflating: single/singleton_fromYellow_Card232.txt.jsonl
#   inflating: single/singleton_fromYellow_Card233.txt.jsonl
#   inflating: single/singleton_fromYellow_Card234.txt.jsonl
#   inflating: single/singleton_fromYellow_Card235.txt.jsonl
#   inflating: single/singleton_fromYellow_Card236.txt.jsonl
#   inflating: single/singleton_fromYellow_Card237.txt.jsonl
#   inflating: single/singleton_fromYellow_Card238.txt.jsonl
#   inflating: single/singleton_fromYellow_Card239.txt.jsonl
#   inflating: single/singleton_fromYellow_Card24.txt.jsonl
#   inflating: single/singleton_fromYellow_Card240.txt.jsonl
#   inflating: single/singleton_fromYellow_Card25.txt.jsonl
#   inflating: single/singleton_fromYellow_Card26.txt.jsonl
#   inflating: single/singleton_fromYellow_Card27.txt.jsonl
#   inflating: single/singleton_fromYellow_Card28.txt.jsonl
#   inflating: single/singleton_fromYellow_Card29.txt.jsonl
#   inflating: single/singleton_fromYellow_Card3.txt.jsonl
#   inflating: single/singleton_fromYellow_Card30.txt.jsonl
#   inflating: single/singleton_fromYellow_Card31.txt.jsonl
#   inflating: single/singleton_fromYellow_Card32.txt.jsonl
#   inflating: single/singleton_fromYellow_Card33.txt.jsonl
#   inflating: single/singleton_fromYellow_Card34.txt.jsonl
#   inflating: single/singleton_fromYellow_Card35.txt.jsonl
#   inflating: single/singleton_fromYellow_Card36.txt.jsonl
#   inflating: single/singleton_fromYellow_Card37.txt.jsonl
#   inflating: single/singleton_fromYellow_Card38.txt.jsonl
#   inflating: single/singleton_fromYellow_Card39.txt.jsonl
#   inflating: single/singleton_fromYellow_Card4.txt.jsonl
#   inflating: single/singleton_fromYellow_Card40.txt.jsonl
#   inflating: single/singleton_fromYellow_Card41.txt.jsonl
#   inflating: single/singleton_fromYellow_Card42.txt.jsonl
#   inflating: single/singleton_fromYellow_Card43.txt.jsonl
#   inflating: single/singleton_fromYellow_Card44.txt.jsonl
#   inflating: single/singleton_fromYellow_Card45.txt.jsonl
#   inflating: single/singleton_fromYellow_Card46.txt.jsonl
#   inflating: single/singleton_fromYellow_Card47.txt.jsonl
#   inflating: single/singleton_fromYellow_Card48.txt.jsonl
#   inflating: single/singleton_fromYellow_Card49.txt.jsonl
#   inflating: single/singleton_fromYellow_Card5.txt.jsonl
#   inflating: single/singleton_fromYellow_Card50.txt.jsonl
#   inflating: single/singleton_fromYellow_Card51.txt.jsonl
#   inflating: single/singleton_fromYellow_Card52.txt.jsonl
#   inflating: single/singleton_fromYellow_Card53.txt.jsonl
#   inflating: single/singleton_fromYellow_Card54.txt.jsonl
#   inflating: single/singleton_fromYellow_Card55.txt.jsonl
#   inflating: single/singleton_fromYellow_Card56.txt.jsonl
#   inflating: single/singleton_fromYellow_Card57.txt.jsonl
#   inflating: single/singleton_fromYellow_Card58.txt.jsonl
#   inflating: single/singleton_fromYellow_Card59.txt.jsonl
#   inflating: single/singleton_fromYellow_Card6.txt.jsonl
#   inflating: single/singleton_fromYellow_Card60.txt.jsonl
#   inflating: single/singleton_fromYellow_Card61.txt.jsonl
#   inflating: single/singleton_fromYellow_Card62.txt.jsonl
#   inflating: single/singleton_fromYellow_Card63.txt.jsonl
#   inflating: single/singleton_fromYellow_Card64.txt.jsonl
#   inflating: single/singleton_fromYellow_Card65.txt.jsonl
#   inflating: single/singleton_fromYellow_Card66.txt.jsonl
#   inflating: single/singleton_fromYellow_Card67.txt.jsonl
#   inflating: single/singleton_fromYellow_Card68.txt.jsonl
#   inflating: single/singleton_fromYellow_Card69.txt.jsonl
#   inflating: single/singleton_fromYellow_Card7.txt.jsonl
#   inflating: single/singleton_fromYellow_Card70.txt.jsonl
#   inflating: single/singleton_fromYellow_Card71.txt.jsonl
#   inflating: single/singleton_fromYellow_Card72.txt.jsonl
#   inflating: single/singleton_fromYellow_Card73.txt.jsonl
#   inflating: single/singleton_fromYellow_Card74.txt.jsonl
#   inflating: single/singleton_fromYellow_Card75.txt.jsonl
#   inflating: single/singleton_fromYellow_Card76.txt.jsonl
#   inflating: single/singleton_fromYellow_Card77.txt.jsonl
#   inflating: single/singleton_fromYellow_Card78.txt.jsonl
#   inflating: single/singleton_fromYellow_Card79.txt.jsonl
#   inflating: single/singleton_fromYellow_Card8.txt.jsonl
#   inflating: single/singleton_fromYellow_Card80.txt.jsonl
#   inflating: single/singleton_fromYellow_Card81.txt.jsonl
#   inflating: single/singleton_fromYellow_Card82.txt.jsonl
#   inflating: single/singleton_fromYellow_Card83.txt.jsonl
#   inflating: single/singleton_fromYellow_Card84.txt.jsonl
#   inflating: single/singleton_fromYellow_Card85.txt.jsonl
#   inflating: single/singleton_fromYellow_Card86.txt.jsonl
#   inflating: single/singleton_fromYellow_Card87.txt.jsonl
#   inflating: single/singleton_fromYellow_Card88.txt.jsonl
#   inflating: single/singleton_fromYellow_Card89.txt.jsonl
#   inflating: single/singleton_fromYellow_Card9.txt.jsonl
#   inflating: single/singleton_fromYellow_Card90.txt.jsonl
#   inflating: single/singleton_fromYellow_Card91.txt.jsonl
#   inflating: single/singleton_fromYellow_Card92.txt.jsonl
#   inflating: single/singleton_fromYellow_Card93.txt.jsonl
#   inflating: single/singleton_fromYellow_Card94.txt.jsonl
#   inflating: single/singleton_fromYellow_Card95.txt.jsonl
#   inflating: single/singleton_fromYellow_Card96.txt.jsonl
#   inflating: single/singleton_fromYellow_Card97.txt.jsonl
#   inflating: single/singleton_fromYellow_Card98.txt.jsonl
#   inflating: single/singleton_fromYellow_Card99.txt.jsonl

# %%
# %pwd
# Out:
# '/content'

# %%
# !pip -q install -U transformers accelerate datasets peft bitsandbytes sentencepiece

# %%
import os, json, random
from dataclasses import dataclass
from typing import Any, Dict, List

import torch
from datasets import Dataset

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    TrainingArguments,
    Trainer,
)

from peft import (
    LoraConfig,
    get_peft_model,
    prepare_model_for_kbit_training,
)

# -----------------------
# 설정
# -----------------------
MODEL_ID  = "beomi/Llama-3-Open-Ko-8B"
DATA_PATH = "kleague_sharegpt_final.jsonl"
OUT_DIR   = "./kl_league_qlora_out_final"

MAX_SEQ_LEN = 1024
TEST_RATIO  = 0.01
SEED        = 42

# A100 권장: bf16
DTYPE = torch.bfloat16

random.seed(SEED)
torch.manual_seed(SEED)

# -----------------------
# 토크나이저
# -----------------------
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)

# Llama 계열은 pad_token이 없는 경우가 많음
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# chat template 사용 가능해야 함 (대부분 Llama-3 파생은 있음)
if getattr(tokenizer, "chat_template", None) is None:
    raise ValueError("이 토크나이저에는 chat_template이 없습니다. apply_chat_template를 쓸 수 없습니다.")

# -----------------------
# 4-bit 로드 (QLoRA)
# -----------------------
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=DTYPE,
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=DTYPE,
)

# 학습 안정 설정
model.config.use_cache = False
model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# -----------------------
# LoRA 타겟 모듈 자동 탐색 (Llama 계열 표준)
# -----------------------
CANDIDATES = ["q_proj","k_proj","v_proj","o_proj","gate_proj","up_proj","down_proj"]

def find_lora_targets(m):
    present = set()
    for name, _ in m.named_modules():
        for c in CANDIDATES:
            if name.endswith(c):
                present.add(c)
    # 보통 전부 잡히지만, 최소한 attention qkv/o는 있어야 함
    if not present:
        raise ValueError("LoRA target_modules를 자동 탐색하지 못했습니다. 모델 구조를 확인하세요.")
    # 학습 효율을 위해 표준 후보만 유지 (순서 고정)
    return [c for c in CANDIDATES if c in present]

target_modules = find_lora_targets(model)
print("LoRA target_modules =", target_modules)

lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=target_modules,
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()

# -----------------------
# 데이터 로딩 + "턴 단위 분해" 전처리
#   - 각 assistant 발화를 하나의 학습 샘플로 만듦
#   - prompt: 이전까지의 messages (system/user/assistant 포함)
#   - completion: 현재 assistant content
#   - labels는 completion 구간만 활성(-100 마스킹)
# -----------------------
def iter_jsonl(path):
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            yield json.loads(line)

def build_features(messages: List[Dict[str, str]], target_idx: int) -> Dict[str, List[int]]:
    """
    messages[target_idx] 가 assistant인 경우:
      - prompt_messages = messages[:target_idx]
      - prompt_text = apply_chat_template(..., add_generation_prompt=True)
      - target_text = assistant content + eos
      - input_ids = prompt_ids + target_ids
      - labels = [-100]*len(prompt_ids) + target_ids
    """
    prompt_messages = messages[:target_idx]
    target_text = messages[target_idx]["content"]

    prompt_text = tokenizer.apply_chat_template(
        prompt_messages,
        tokenize=False,
        add_generation_prompt=True,   # 여기서 assistant 시작 토큰/헤더가 붙음
    )

    # prompt는 특수토큰 포함 문자열이므로 add_special_tokens=False 권장
    prompt_ids = tokenizer(prompt_text, add_special_tokens=False).input_ids
    target_ids = tokenizer(target_text + tokenizer.eos_token, add_special_tokens=False).input_ids

    input_ids = prompt_ids + target_ids
    labels    = [-100] * len(prompt_ids) + target_ids
    attention_mask = [1] * len(input_ids)

    # 길이 초과 시, 뒤쪽(최근 컨텍스트/정답)을 살리도록 좌측 truncation
    if len(input_ids) > MAX_SEQ_LEN:
        input_ids = input_ids[-MAX_SEQ_LEN:]
        attention_mask = attention_mask[-MAX_SEQ_LEN:]
        labels = labels[-MAX_SEQ_LEN:]

    return {
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "labels": labels,
    }

all_rows = []
for rec in iter_jsonl(DATA_PATH):
    messages = rec.get("messages", [])
    # 안전 필터: role/content만 보장
    clean = []
    for m in messages:
        if "role" in m and "content" in m:
            clean.append({"role": m["role"], "content": m["content"]})
    # 각 assistant 턴을 샘플로 생성
    for i, m in enumerate(clean):
        if m["role"] == "assistant":
            feat = build_features(clean, i)
            all_rows.append(feat)

print("num training samples =", len(all_rows))

# train/valid split
random.shuffle(all_rows)
n_valid = max(1, int(len(all_rows) * TEST_RATIO))
valid_rows = all_rows[:n_valid]
train_rows = all_rows[n_valid:]

train_ds = Dataset.from_list(train_rows)
valid_ds = Dataset.from_list(valid_rows)

# -----------------------
# Data collator (labels 포함 padding)
# -----------------------
@dataclass
class CausalLMCollator:
    tokenizer: Any

    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, torch.Tensor]:
        input_features = {
            "input_ids": [f["input_ids"] for f in features],
            "attention_mask": [f["attention_mask"] for f in features],
        }
        batch = self.tokenizer.pad(
            input_features,
            padding=True,
            return_tensors="pt",
        )

        max_len = batch["input_ids"].shape[1]
        labels = torch.full((len(features), max_len), -100, dtype=torch.long)

        for i, f in enumerate(features):
            l = len(f["labels"])
            labels[i, :l] = torch.tensor(f["labels"], dtype=torch.long)

        batch["labels"] = labels
        return batch

data_collator = CausalLMCollator(tokenizer)

# -----------------------
# TrainingArguments
# -----------------------
os.makedirs(OUT_DIR, exist_ok=True)

training_args = TrainingArguments(
    output_dir=OUT_DIR,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=8,     # 메모리 여유 있으면 4로 줄이고 batch_size 늘려도 됨
    learning_rate=2e-4,
    num_train_epochs=2,
    lr_scheduler_type="cosine",
    warmup_ratio=0.03,
    weight_decay=0.0,

    logging_steps=20,
    save_steps=200,
    eval_steps=200,
    eval_strategy="steps",
    save_total_limit=2,

    bf16=True,                         # A100 권장
    fp16=False,
    optim="paged_adamw_8bit",          # bitsandbytes 옵티마이저
    report_to="none",
    seed=SEED,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=valid_ds,
    data_collator=data_collator,
)

trainer.train()

# -----------------------
# 어댑터 저장 (QLoRA 결과물)
# -----------------------
ADAPTER_DIR = os.path.join(OUT_DIR, "adapter")
trainer.model.save_pretrained(ADAPTER_DIR)
tokenizer.save_pretrained(ADAPTER_DIR)
print("saved adapter to:", ADAPTER_DIR)

# -----------------------
# (선택) 어댑터를 베이스에 병합해서 단일 모델로 저장
#   - 병합은 fp16/bf16 베이스 모델로 다시 로드 후 진행
# -----------------------
from peft import PeftModel

MERGED_DIR = os.path.join(OUT_DIR, "merged")

base_fp = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=DTYPE,
)

merged = PeftModel.from_pretrained(base_fp, ADAPTER_DIR)
merged = merged.merge_and_unload()

os.makedirs(MERGED_DIR, exist_ok=True)
merged.save_pretrained(MERGED_DIR, safe_serialization=True)
tokenizer.save_pretrained(MERGED_DIR)
print("saved merged model to:", MERGED_DIR)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/698 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/3.00G [00:00<?, ?B/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/2.94G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/2.94G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/2.97G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/1.29G [00:00<?, ?B/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/2.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# LoRA target_modules = ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj']
# trainable params: 41,943,040 || all params: 8,072,204,288 || trainable%: 0.5196
# num training samples = 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4086971668.py in <cell line: 0>()
#     250 )
#     251
# --> 252 trainer.train()
#     253
#     254 # -----------------------
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323                 hf_hub_utils.enable_progress_bars()
#    2324         else:
# -> 2325             return inner_training_loop(
#    2326                 args=args,
#    2327                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2373         logger.debug(f"Currently training with a batch size of: {self._train_batch_size}")
#    2374         # Data loader and number of training steps
# -> 2375         train_dataloader = self.get_train_dataloader()
#    2376         if self.is_fsdp_xla_v2_enabled:
#    2377             train_dataloader = tpu_spmd_dataloader(train_dataloader)
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in get_train_dataloader(self)
#    1138             raise ValueError("Trainer: training requires a train_dataset.")
#    1139
# -> 1140         return self._get_dataloader(
#    1141             dataset=self.train_dataset,
#    1142             description="Training",
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _get_dataloader(self, dataset, description, batch_size, sampler_fn, is_training, dataloader_key)
#    1093         data_collator = self.data_collator
#    1094         if is_datasets_available() and isinstance(dataset, datasets.Dataset):
# -> 1095             dataset = self._remove_unused_columns(dataset, description=description)
#    1096         else:
#    1097             data_collator = self._get_collator_with_removed_columns(self.data_collator, description=description)
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _remove_unused_columns(self, dataset, description)
#    1019         columns = [k for k in signature_columns if k in dataset.column_names]
#    1020         if len(columns) == 0:
# -> 1021             raise ValueError(
#    1022                 f"No columns in the dataset match the model's forward method signature: ({', '.join(signature_columns)}). "
#    1023                 f"The following columns have been ignored: [{', '.join(ignored_columns)}]. "
#
# ValueError: No columns in the dataset match the model's forward method signature: (input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, kwargs, label, labels, label_ids). The following columns have been ignored: []. Please check the dataset and model. You may need to set `remove_unused_columns=False` in `TrainingArguments`.

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

MERGED_DIR = "./kl_league_qlora_out/merged"  # 위에서 저장한 경로

tok = AutoTokenizer.from_pretrained(MERGED_DIR, use_fast=True)
mdl = AutoModelForCausalLM.from_pretrained(
    MERGED_DIR,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)

messages = [
    {"role": "system", "content": "너는 축구 경기 동반 시청 파트너다. 항상 B(assistant)로서 다음 한 문장만 출력한다."},
    {"role": "user", "c9ontent": "패스 미스 너무 많다."},
]
messages = [
    {"role":"system","content":"\n너는 축구 경기 동반 시청 파트너다. 너는 감정 표현이 강한 톤으로 반응한다. 금지어/혐오/차별/폭력 조장/인신공격은 금지한다. 항상 B(assistant)의 다음 한 문장만 출력한다.\n"},
    {"role":"user","content":"['Description of a Soccer Game']\n    축구는 두 팀이 공을 상대 골문에 넣어 득점하는 경기다.\n    경기 시간은 전반 45분 + 후반 45분(총 90분). 필요 시 추가시간(Added Time)이 부여될 수 있다.\n    한 팀은 보통 11명(골키퍼 포함)으로 구성된다.\n    [Profanity Policy]\n    Forbidden : \"씨발/시발/ㅅㅂ/ㅆㅂ\", \"좆\", \"병신\", \"지랄\", \"개새끼\", \"새끼\", \"꺼져\", \"닥쳐\", \"엿먹”\n    ['Current Soccer Game Situation']\n    전반전\n177.867 sec, 김현서(인천 유나이티드), main_pos(CM) , now_pos(nan) , 선수가 공중, 지상, 루즈볼 경합에서 승리함\n178.950 sec, 무고사(인천 유나이티드), main_pos(CF) , now_pos(CF) , 선수가 소유권이 없는 공(루즈볼)을 다시 획득\n178.950 sec, 무고사(인천 유나이티드), main_pos(CF) , now_pos(CF) , 선수가 팀 동료에게 공을 성공적으로 패스\n181.518 sec, 박승호(인천 유나이티드), main_pos(RW) , now_pos(RW) , 선수가 공중, 지상, 루즈볼 경합에서 승리함\n181.518 sec, 박승호(인천 유나이티드), main_pos(RW) , now_pos(RW) , 선수가 팀 동료에게 공을 성공적으로 패스 받음\n181.518 sec, 박승호(인천 유나이티드), main_pos(RW) , now_pos(RW) , 선수가 팀 동료에게 공을 성공적으로 패스\n183.211 sec, 홍시후(인천 유나이티드), main_pos(RWB) , now_pos(LW) , 선수가 팀 동료에게 공을 성공적으로 패스 받음\n183.921 sec, 홍시후(인천 유나이티드), main_pos(RWB) , now_pos(LW) , 선수가 팀 동료에게 공을 성공적으로 패스\n185.075 sec, 김연수(인천 유나이티드), main_pos(CB) , now_pos(CB) , 선수가 팀 동료에게 공을 성공적으로 패스 받음\n185.075 sec, 김연수(인천 유나이티드), main_pos(CB) , now_pos(CB) , 선수가 팀 동료에게 공을 성공적으로 패스\n187.500 sec, 박승호(인천 유나이티드), main_pos(RW) , now_pos(RW) , 선수가 팀 동료에게 공을 성공적으로 패스 받음\n187.501 sec, 박승호(인천 유나이티드), main_pos(RW) , now_pos(RW) , 선수가 공을 몰고 이동하는 행동\n190.067 sec, 이명재(울산 HD FC), main_pos(LB) , now_pos(LB) , 파울을 저질렀으나 카드를 받지 않음\n    ['과제(Task)']\n    현재 진행 중인 경기에 대해 A와 B 두 사람이 이야기하고 있다. 두 사람 모두 울산 HD FC의 팬이며, B의 감정 표현은 매우 적극적이다(High arousal).\n    위의 축구 경기 설명과 현재 상황을 바탕으로, Person B의 대화 응답을 생성하라.\n    ['Person B의 행동 가이드라인(Behavioral Guidelines for Person B)']\n    행동이 울산 HD FC에 유리하면: B는 그 행동을 좋아한다.\n    행동이 울산 HD FC에 불리하면: B는 거친 표현을 한다.(쌍욕은 금지)\n    커뮤니티체(은어, 이모지, 'ㅋ/ㅎ/ㅠ,?,!' 반복)를 사용하세요.\n    문법에 얽매이지 말고 짧고 강렬하게 반응하세요.\n    실제로 채팅을 치는 것 처럼 9단어 이내로 문장을 완성하세요"},
    {"role":"user","content":"뭐야!?"}


]

prompt = tok.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tok(prompt, return_tensors="pt").to(mdl.device)

with torch.no_grad():
    out = mdl.generate(
        **inputs,
        max_new_tokens=40,
        do_sample=True,
        temperature=0.8,
        top_p=0.9,
        repetition_penalty=1.05,
        eos_token_id=tok.eos_token_id,
    )

print(tok.decode(out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip())
# Out:
# The tokenizer you are loading from './kl_league_qlora_out/merged' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# 와 진짜 개답답하네ㅋㅋ 뭐하냐;;

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

MERGED_DIR = "./kl_league_qlora_out/merged"  # 위에서 저장한 경로

tok = AutoTokenizer.from_pretrained(MERGED_DIR, use_fast=True)
mdl = AutoModelForCausalLM.from_pretrained(
    MERGED_DIR,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)

messages = [
    {"role": "system", "content": "너는 축구 경기 동반 시청 파트너다. 항상 B(assistant)로서 다음 한 문장만 출력한다."},
    {"role": "user", "c9ontent": "패스 미스 너무 많다."},
]
messages =  [
    {"role": "system", "content": "['Description of a Soccer Game']\n축구는 두 팀이 공을 상대 골문에 넣어 득점하는 경기다.\n경기 시간은 전반 45분 + 후반 45분(총 90분). 필요 시 추가시간(Added Time)이 부여될 수 있다.\n한 팀은 보통 11명(골키퍼 포함)으로 구성된다.\n\n['Current Soccer Game Situation']\n**context**\n\n**trigger**\n[90:03] [울산 HD FC] 이동경: 프리킥 슈팅(실패) - 우리 팀에게 매우 긍정적 (VAEP: +0.1088)\n\n['과제(Task)']\n현재 진행 중인 경기에 대해 A와 B 두 사람이 이야기하고 있다. 두 사람 모두 울산 HD FC의 팬이며, B의 감정 표현은 매우 적극적이다(High arousal).\n위의 축구 경기 설명과 현재 상황을 바탕으로, Person B의 대화 응답을 생성하라.\n\n['Person B의 행동 가이드라인(Behavioral Guidelines for Person B)']\n행동이 울산 HD FC에 유리하면: B는 그 행동을 좋아한다.\n행동이 울산 HD FC에 불리하면: B는 거친 비속어를 표현한다.(쌍욕은 금지)\n커뮤니티체(은어, 이모지, 'ㅋ/ㅎ/ㅠ,?,!' 반복)를 사용하세요.\n문법에 얽매이지 말고 짧고 강렬하게 반응하세요.\n실제로 채팅을 치는 것 처럼 9단어 이내로 문장을 완성하세요\n\nfan_team: 울산 HD FC"},
     {"role": "user", "content": "와 이동경 프리킥 막혔다, 진짜 다행이다."},
      {"role": "assistant", "content": "캬 거기서 막아주네 미쳤다ㅋㅋ"},
     {"role": "user", "content": "VAEP도 긍정적으로 떴네, 큰일 넘겼다."},
     {"role": "assistant", "content": "와 진짜 심장 쫄깃 ㅋㅋ 기회 살렸다!"},
     {"role": "user", "content": "이제 추가시간 버티면 끝난다."}]
# {"role": "assistant", "content": "버텨라 울산! 심장 터진다ㅠㅠ"}

prompt = tok.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tok(prompt, return_tensors="pt").to(mdl.device)

with torch.no_grad():
    out = mdl.generate(
        **inputs,
        max_new_tokens=40,
        do_sample=True,
        temperature=0.8,
        top_p=0.9,
        repetition_penalty=1.05,
        eos_token_id=tok.eos_token_id,
    )

print(tok.decode(out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip())
# Out:
# The tokenizer you are loading from './kl_league_qlora_out/merged' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# 버텨라 울산! 심장 터진다ㅠㅠ

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

MERGED_DIR = "./kl_league_qlora_out/merged"  # 위에서 저장한 경로

tok = AutoTokenizer.from_pretrained(MERGED_DIR, use_fast=True)
mdl = AutoModelForCausalLM.from_pretrained(
    MERGED_DIR,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)

messages = [
    {"role": "system", "content": "너는 축구 경기 동반 시청 파트너다. 항상 B(assistant)로서 다음 한 문장만 출력한다."},
    {"role": "user", "c9ontent": "패스 미스 너무 많다."},
]
messages =  [
    {"role": "system", "content": "['Description of a Soccer Game']\n축구는 두 팀이 공을 상대 골문에 넣어 득점하는 경기다.\n경기 시간은 전반 45분 + 후반 45분(총 90분). 필요 시 추가시간(Added Time)이 부여될 수 있다.\n한 팀은 보통 11명(골키퍼 포함)으로 구성된다.\n\n['Current Soccer Game Situation']\n**context**\n\n**trigger**\n[90:03] [울산 HD FC] 이동경: 프리킥 슈팅(실패) - 우리 팀에게 매우 긍정적 (VAEP: +0.1088)\n\n['과제(Task)']\n현재 진행 중인 경기에 대해 A와 B 두 사람이 이야기하고 있다. 두 사람 모두 울산 HD FC의 팬이며, B의 감정 표현은 매우 적극적이다(High arousal).\n위의 축구 경기 설명과 현재 상황을 바탕으로, Person B의 대화 응답을 생성하라.\n\n['Person B의 행동 가이드라인(Behavioral Guidelines for Person B)']\n행동이 울산 HD FC에 유리하면: B는 그 행동을 좋아한다.\n행동이 울산 HD FC에 불리하면: B는 거친 비속어를 표현한다.(쌍욕은 금지)\n커뮤니티체(은어, 이모지, 'ㅋ/ㅎ/ㅠ,?,!' 반복)를 사용하세요.\n문법에 얽매이지 말고 짧고 강렬하게 반응하세요.\n실제로 채팅을 치는 것 처럼 9단어 이내로 문장을 완성하세요\n\nfan_team: 울산 HD FC"},
     {"role": "user", "content": "와 이동경 프리킥 막혔다, 진짜 다행이다."}]
#      {"role": "assistant", "content": "캬 거기서 막아주네 미쳤다ㅋㅋ"}]
#     {"role": "user", "content": "VAEP도 긍정적으로 떴네, 큰일 넘겼다."},
#     {"role": "assistant", "content": "와 진짜 심장 쫄깃 ㅋㅋ 기회 살렸다!"},
#     {"role": "user", "content": "이제 추가시간 버티면 끝난다."}]
# {"role": "assistant", "content": "버텨라 울산! 심장 터진다ㅠㅠ"}

prompt = tok.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tok(prompt, return_tensors="pt").to(mdl.device)

with torch.no_grad():
    out = mdl.generate(
        **inputs,
        max_new_tokens=40,
        do_sample=True,
        temperature=0.8,
        top_p=0.9,
        repetition_penalty=1.05,
        eos_token_id=tok.eos_token_id,
    )

print(tok.decode(out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip())
# Out:
# The tokenizer you are loading from './kl_league_qlora_out/merged' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# 와 진짜 개꿀ㅋㅋㅋㅋ 심장 쫄렸잖아;;

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
#/content/drive/MyDrive/model/kl_league_qlora_out
MERGED_DIR = "/content/drive/MyDrive/model/kl_league_qlora_out/merged"  # 위에서 저장한 경로

tok = AutoTokenizer.from_pretrained(MERGED_DIR, use_fast=True)
mdl = AutoModelForCausalLM.from_pretrained(
    MERGED_DIR,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)

messages = [
    {"role": "system", "content": "너는 축구 경기 동반 시청 파트너다. 항상 B(assistant)로서 다음 한 문장만 출력한다."},
    {"role": "user", "c9ontent": "패스 미스 너무 많다."},
]
messages =  [
    {"role": "system", "content": "['Description of a Soccer Game']\n축구는 두 팀이 공을 상대 골문에 넣어 득점하는 경기다.\n경기 시간은 전반 45분 + 후반 45분(총 90분). 필요 시 추가시간(Added Time)이 부여될 수 있다.\n한 팀은 보통 11명(골키퍼 포함)으로 구성된다.\n\n['Current Soccer Game Situation']\n**context**\n\n**trigger**\n[90:03] [울산 HD FC] 이동경: 프리킥 슈팅(실패) - 우리 팀에게 매우 긍정적 (VAEP: +0.1088)\n\n['과제(Task)']\n현재 진행 중인 경기에 대해 A와 B 두 사람이 이야기하고 있다. 두 사람 모두 울산 HD FC의 팬이며, B의 감정 표현은 매우 적극적이다(High arousal).\n위의 축구 경기 설명과 현재 상황을 바탕으로, Person B의 대화 응답을 생성하라.\n\n['Person B의 행동 가이드라인(Behavioral Guidelines for Person B)']\n행동이 울산 HD FC에 유리하면: B는 그 행동을 좋아한다.\n행동이 울산 HD FC에 불리하면: B는 거친 비속어를 표현한다.(쌍욕은 금지)\n커뮤니티체(은어, 이모지, 'ㅋ/ㅎ/ㅠ,?,!' 반복)를 사용하세요.\n문법에 얽매이지 말고 짧고 강렬하게 반응하세요.\n실제로 채팅을 치는 것 처럼 9단어 이내로 문장을 완성하세요\n\nfan_team: 울산 HD FC"},
     {"role": "user", "content": "와 이동경 프리킥 막혔다, 진짜 다행이다."}]
#      {"role": "assistant", "content": "캬 거기서 막아주네 미쳤다ㅋㅋ"}]
#     {"role": "user", "content": "VAEP도 긍정적으로 떴네, 큰일 넘겼다."},
#     {"role": "assistant", "content": "와 진짜 심장 쫄깃 ㅋㅋ 기회 살렸다!"},
#     {"role": "user", "content": "이제 추가시간 버티면 끝난다."}]
# {"role": "assistant", "content": "버텨라 울산! 심장 터진다ㅠㅠ"}

prompt = tok.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tok(prompt, return_tensors="pt").to(mdl.device)

with torch.no_grad():
    out = mdl.generate(
        **inputs,
        max_new_tokens=40,
        do_sample=True,
        temperature=0.8,
        top_p=0.9,
        repetition_penalty=1.05,
        eos_token_id=tok.eos_token_id,
    )

print(tok.decode(out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip())
# Out:
# The tokenizer you are loading from '/content/drive/MyDrive/model/kl_league_qlora_out/merged' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# 아 개꿀ㅋㅋ 저게 왜 안 들어가냐!
